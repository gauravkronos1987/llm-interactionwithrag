# %%
from ingest import load_faq_data,build_index

# %%
from rag_helper import RAGBase

# %%
documents = load_faq_data()
index= build_index(documents)
print(f"Loaded {len(documents)} documents.")
# Out:
# Loaded 1208 documents.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
answer = RAGBase(index,openai_client).rag("I have just joined discovered this course, what is it about?")
print(answer)
# Out:
# It’s the **LLM Zoomcamp** course, which focuses on **large language models (LLMs)** and **retrieval-augmented generation (RAG)**.
#
# If you want, I can also give you a short summary of the course structure.
